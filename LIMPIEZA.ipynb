# %% [markdown]
# <a href="https://colab.research.google.com/github/danielamonavas1986/clases-DATA-SCIENCE/blob/main/LIMPIEZA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Ejemplo procesamiento de atípicos en un Data Frame**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import stats
import seaborn as sns

# %%
from sklearn.datasets import fetch_california_housing
ca = fetch_california_housing()

# %%
ca
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]]),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894]),
#  'frame': None,
#  'target_names': ['MedHouseVal'],
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
#   'AveOccup',
#   'Latitude',
# ...

# %%
dir(ca)
# Out:
# ['DESCR', 'data', 'feature_names', 'frame', 'target', 'target_names']

# %%
X = ca.data
y = ca.target

# %%
data = np.concatenate((X,y.reshape(-1,1)), axis=1)

# %%
df = pd.DataFrame(data, columns=ca.feature_names+['target'])
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  target
# 0    -122.23   4.526
# 1    -122.22   3.585
# 2    -122.24   3.521
# 3    -122.25   3.413
# 4    -122.25   3.422

# %%
df.drop(['Latitude', 'Longitude'], axis=1, inplace=True)

# %%
features = ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',]
features
# Out:
# ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup']

# %%
sns.set_style('dark')
for col in features:
    plt.figure(figsize=(15,4))
    plt.subplot(131)
    sns.distplot(df[col], label="skew: " + str(np.round(df[col].skew(),2)))
    plt.legend()
    plt.subplot(132)
    sns.boxplot(df[col])
    plt.subplot(133)
    stats.probplot(df[col], plot=plt)
    plt.tight_layout()
    plt.show()
# Out:
# <ipython-input-11-d5994be2638e>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col], label="skew: " + str(np.round(df[col].skew(),2)))
# <ipython-input-11-d5994be2638e>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
df_cap = df.copy()

# %%
def percentile_capping(df, cols, from_low_end, from_high_end):
    
    for col in cols:
        
#         lower_bound = df[col].quantile(from_low_end)
#         upper_bound = df[col].quantile(1-from_high_end)
        
#         df[col] = np.where(df[col]>upper_bound, upper_bound,
#                  np.where(df[col]<lower_bound, lower_bound, df[col]))

        stats.mstats.winsorize(a=df[col], limits=(from_low_end, from_high_end), inplace=True)

# %%
# fourth argument of 0.01 from right end is equivalent to saying
# 1-0.01 = 0.99 quantile from the left end
percentile_capping(df_cap, features, 0.01, 0.01)

# %%
df_cap.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.852245     28.648692      5.334211      1.077082   1404.023692
# std        1.804005     12.566882      1.321745      0.158560    972.980477
# min        1.068500      4.000000      2.581006      0.872727     88.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       10.598100     52.000000     10.359649      2.127753   5807.000000
#
#            AveOccup        target
# count  20640.000000  20640.000000
# mean       2.916378      2.068558
# std        0.732341      1.153956
# min        1.536605      0.149990
# 25%        2.429741      1.196000
# 50%        2.818116      1.797000
# 75%        3.282261      2.647250
# ...

# %%
df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup        target
# count  20640.000000  20640.000000
# mean       3.070655      2.068558
# std       10.386050      1.153956
# min        0.692308      0.149990
# 25%        2.429741      1.196000
# 50%        2.818116      1.797000
# 75%        3.282261      2.647250
# ...

# %%
for col in features:
    plt.figure(figsize=(16,4))
    
    plt.subplot(141)
    sns.distplot(df[col], label="skew: " + str(np.round(df[col].skew(),2)))
    plt.title('Before')
    plt.legend()
    
    plt.subplot(142)
    sns.distplot(df_cap[col], label="skew: " + str(np.round(df_cap[col].skew(),2)))
    plt.title('After')
    plt.legend()
    
    plt.subplot(143)
    sns.boxplot(df[col])
    plt.title('Before')
    
    plt.subplot(144)
    sns.boxplot(df_cap[col])
    plt.title('After')
    plt.tight_layout()
    plt.show()
# Out:
# <ipython-input-17-436be8b32339>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col], label="skew: " + str(np.round(df[col].skew(),2)))
# <ipython-input-17-436be8b32339>:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
# fourth argument of 0.01 from right end is equivalent to saying
# 1-0.51 = 0.95 quantile from the left end
percentile_capping(df_cap, features, 0.05, 0.05)

# %%
df_cap.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.787419     28.769186      5.300187      1.061449   1352.935465
# std        1.562737     12.350935      1.135379      0.081860    775.085867
# min        1.600600      8.000000      3.432331      0.939130    348.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max        7.300300     52.000000      7.640227      1.272997   3288.000000
#
#            AveOccup        target
# count  20640.000000  20640.000000
# mean       2.900206      2.068558
# std        0.651978      1.153956
# min        1.872549      0.149990
# 25%        2.429741      1.196000
# 50%        2.818116      1.797000
# 75%        3.282261      2.647250
# ...

# %%
df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup        target
# count  20640.000000  20640.000000
# mean       3.070655      2.068558
# std       10.386050      1.153956
# min        0.692308      0.149990
# 25%        2.429741      1.196000
# 50%        2.818116      1.797000
# 75%        3.282261      2.647250
# ...

# %%
for col in features:
    plt.figure(figsize=(16,4))
    
    plt.subplot(141)
    sns.distplot(df[col], label="skew: " + str(np.round(df[col].skew(),2)))
    plt.title('Before')
    plt.legend()
    
    plt.subplot(142)
    sns.distplot(df_cap[col], label="skew: " + str(np.round(df_cap[col].skew(),2)))
    plt.title('After')
    plt.legend()
    
    plt.subplot(143)
    sns.boxplot(df[col])
    plt.title('Before')
    
    plt.subplot(144)
    sns.boxplot(df_cap[col])
    plt.title('After')
    plt.tight_layout()
    plt.show()
# Out:
# <ipython-input-21-436be8b32339>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col], label="skew: " + str(np.round(df[col].skew(),2)))
# <ipython-input-21-436be8b32339>:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
# fourth argument of 0.01 from right end is equivalent to saying
# 1-0.10 = 0.90 quantile from the left end
percentile_capping(df_cap, features, 0.10, 0.10)

# %%
df_cap.describe()
# Out:
#              MedInc     HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.00000  20640.000000  20640.000000  20640.000000
# mean       3.729510     28.69564      5.277295      1.056468   1312.810320
# std        1.371674     10.98742      1.005705      0.063896    646.821079
# min        1.903800     13.00000      3.790936      0.966418    510.000000
# 25%        2.563400     18.00000      4.440716      1.006079    787.000000
# 50%        3.534800     29.00000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.00000      6.052381      1.099526   1725.000000
# max        6.159200     46.00000      6.961165      1.172727   2566.000000
#
#            AveOccup        target
# count  20640.000000  20640.000000
# mean       2.882329      2.068558
# std        0.565283      1.153956
# min        2.075650      0.149990
# 25%        2.429741      1.196000
# 50%        2.818116      1.797000
# 75%        3.282261      2.647250
# ...

# %%
df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup        target
# count  20640.000000  20640.000000
# mean       3.070655      2.068558
# std       10.386050      1.153956
# min        0.692308      0.149990
# 25%        2.429741      1.196000
# 50%        2.818116      1.797000
# 75%        3.282261      2.647250
# ...

# %%
for col in features:
    plt.figure(figsize=(16,4))
    
    plt.subplot(141)
    sns.distplot(df[col], label="skew: " + str(np.round(df[col].skew(),2)))
    plt.title('Before')
    plt.legend()
    
    plt.subplot(142)
    sns.distplot(df_cap[col], label="skew: " + str(np.round(df_cap[col].skew(),2)))
    plt.title('After')
    plt.legend()
    
    plt.subplot(143)
    sns.boxplot(df[col])
    plt.title('Before')
    
    plt.subplot(144)
    sns.boxplot(df_cap[col])
    plt.title('After')
    plt.tight_layout()
    plt.show()
# Out:
# <ipython-input-25-436be8b32339>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col], label="skew: " + str(np.round(df[col].skew(),2)))
# <ipython-input-25-436be8b32339>:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# En este caso ya se han corregido todos los atípicos. Ningún boxplot muestra outliers.

# %% [markdown]
# ## **Multicolinealidad**

# %%
import pandas as pd

# Calcula la matriz de correlación
correlation_matrix1 = df.corr()

# Visualiza la matriz de correlación
print(correlation_matrix1)
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge   -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms    0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms  -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population  0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup    0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# target      0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#               target
# MedInc      0.688075
# HouseAge    0.105623
# AveRooms    0.151948
# AveBedrms  -0.046701
# Population -0.024650
# AveOccup   -0.023737
# target      1.000000

# %%
import pandas as pd

# Calcula la matriz de correlación
correlation_matrix2 = df_cap.corr()

# Visualiza la matriz de correlación
print(correlation_matrix2)
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.147511  0.661513  -0.251919   -0.003466 -0.065811
# HouseAge   -0.147511  1.000000 -0.232791  -0.120225   -0.303365 -0.008731
# AveRooms    0.661513 -0.232791  1.000000   0.094826   -0.097531 -0.024300
# AveBedrms  -0.251919 -0.120225  0.094826   1.000000    0.005801 -0.121646
# Population -0.003466 -0.303365 -0.097531   0.005801    1.000000  0.234353
# AveOccup   -0.065811 -0.008731 -0.024300  -0.121646    0.234353  1.000000
# target      0.659111  0.099378  0.308565  -0.099717   -0.037742 -0.279999
#
#               target
# MedInc      0.659111
# HouseAge    0.099378
# AveRooms    0.308565
# AveBedrms  -0.099717
# Population -0.037742
# AveOccup   -0.279999
# target      1.000000

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Calcula el VIF para cada variable
X = df[['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population','AveOccup']]  # Variables predictoras
vif = pd.DataFrame()
vif["Variable"] = X.columns
vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# Visualiza los valores de VIF
print(vif)
# Out:
#      Variable        VIF
# 0      MedInc   7.766787
# 1    HouseAge   4.309941
# 2    AveRooms  41.111592
# 3   AveBedrms  34.118257
# 4  Population   2.322315
# 5    AveOccup   1.094793

# %%
# MedInc	HouseAge	AveRooms	AveBedrms	Population	AveOccup

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Calcula el VIF para cada variable
X = df_cap[['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population','AveOccup']]  # Variables predictoras
vif = pd.DataFrame()
vif["Variable"] = X.columns
vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# Visualiza los valores de VIF
print(vif)
# Out:
#      Variable        VIF
# 0      MedInc  16.466293
# 1    HouseAge   8.577253
# 2    AveRooms  62.399970
# 3   AveBedrms  65.980154
# 4  Population   6.248182
# 5    AveOccup  25.955738

# %%
# MedInc	HouseAge	AveRooms	AveBedrms	Population	AveOccup

# %% [markdown]
# Tenemos VIFs mayores a 10 -- Alto grado de multicolinealidad

# %%
from sklearn.linear_model import Ridge, Lasso

# %%
import pandas as pd
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Obtener las variables predictoras (X) y la variable dependiente (Y) del DataFrame
X = df[['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population','AveOccup']]
Y = df['target']

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# Crear y entrenar el modelo de regresión Ridge
ridge = Ridge(alpha=1.0)  # Parámetro de regularización (ajustar según sea necesario)
ridge.fit(X_train, Y_train)

# Realizar predicciones en el conjunto de prueba
Y_pred = ridge.predict(X_test)

# Calcular el error cuadrático medio (MSE)
mse = mean_squared_error(Y_test, Y_pred)

# Imprimir el MSE
print("Error cuadrático medio (MSE):", mse)
# Out:
# Error cuadrático medio (MSE): 0.6193102669457953

# %%
import pandas as pd
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Obtener las variables predictoras (X) y la variable dependiente (Y) del DataFrame
X = df_cap[['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population','AveOccup']]
Y = df_cap['target']

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# Crear y entrenar el modelo de regresión Ridge
ridge = Ridge(alpha=1.0)  # Parámetro de regularización (ajustar según sea necesario)
ridge.fit(X_train, Y_train)

# Realizar predicciones en el conjunto de prueba
Y_pred = ridge.predict(X_test)

# Calcular el error cuadrático medio (MSE)
mse = mean_squared_error(Y_test, Y_pred)

# Imprimir el MSE
print("Error cuadrático medio (MSE):", mse)
# Out:
# Error cuadrático medio (MSE): 0.5914416228086541

# %% [markdown]
# El MSE del modelo limpio es inferior. debemos cambiar el coeficiente hasta minimizar el MSE.

# %%
import pandas as pd
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Obtener las variables predictoras (X) y la variable dependiente (Y) del DataFrame
X = df_cap[['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population','AveOccup']]
Y = df_cap['target']

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# Crear y entrenar el modelo de regresión Ridge
ridge = Ridge(alpha=1.0)  # Parámetro de regularización (ajustar según sea necesario)
ridge.fit(X_train, Y_train)

# Realizar predicciones en el conjunto de prueba
Y_pred = ridge.predict(X_test)

# Calcular el error cuadrático medio (MSE)
mse = mean_squared_error(Y_test, Y_pred)

# Imprimir el MSE
print("Error cuadrático medio (MSE):", mse)

# %%
import numpy as np
from sklearn.linear_model import RidgeCV
from sklearn.model_selection import train_test_split

# Obtener las variables predictoras (X) y la variable dependiente (Y) del DataFrame
X = df_cap[['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population','AveOccup']]
Y = df_cap['target']

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# Definir los posibles valores de alpha a probar
alphas = np.logspace(-4, 2, num=100)

# Crear el modelo de regresión Ridge con validación cruzada
ridge_cv = RidgeCV(alphas=alphas)

# Entrenar el modelo con los datos de entrenamiento
ridge_cv.fit(X_train, Y_train)

# Obtener el valor óptimo de alpha
optimal_alpha = ridge_cv.alpha_

# Imprimir el valor óptimo de alpha
print("Valor óptimo de alpha:", optimal_alpha)
# Out:
# Valor óptimo de alpha: 0.14174741629268048

# %%
import pandas as pd
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Obtener las variables predictoras (X) y la variable dependiente (Y) del DataFrame
X = df_cap[['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population','AveOccup']]
Y = df_cap['target']

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# Crear y entrenar el modelo de regresión Ridge
ridge = Ridge(alpha=optimal_alpha)  # Parámetro de regularización (ajustar según sea necesario)
ridge.fit(X_train, Y_train)

# Realizar predicciones en el conjunto de prueba
Y_pred = ridge.predict(X_test)

# Calcular el error cuadrático medio (MSE)
mse = mean_squared_error(Y_test, Y_pred)

# Imprimir el MSE
print("Error cuadrático medio (MSE):", mse)
# Out:
# Error cuadrático medio (MSE): 0.5913376833456705

# %% [markdown]
# Este modelo corrige la multicolinealidad y proporciona el mejor modelo, es decir, el de menor MSE.

# %% [markdown]
# ## **Análisis de los residuos**

# %%
# Obtener los residuos
residuos = Y_test - Y_pred

# %%
# Crear un DataFrame con la variable de residuos
residuos = pd.DataFrame({'residuos': residuos})

# Imprimir el DataFrame
residuos
# Out:
#        residuos
# 14740 -0.374931
# 10101 -0.724188
# 20566 -0.295899
# 2670  -0.932136
# 15709  1.197246
# ...         ...
# 6655   0.096999
# 3505  -0.403230
# 1919  -0.147234
# 1450  -0.533328
# 4148  -0.497779
#
# [4128 rows x 1 columns]

# %%
import seaborn as sns

# Visualizar la distribución de los residuos
sns.histplot(residuos, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
import matplotlib.pyplot as plt

# Crear el gráfico de puntos
plt.scatter(residuos.index, residuos['residuos'])

# Agregar etiquetas y título al gráfico
plt.xlabel('Índice')
plt.ylabel('Residuos')
plt.title('Gráfico de Puntos de Residuos')

# Mostrar el gráfico
plt.show()

# %%
residuos.describe()
# Out:
#           residuos
# count  4128.000000
# mean     -0.011202
# std       0.768996
# min      -3.240493
# 25%      -0.512765
# 50%      -0.123581
# 75%       0.356848
# max       4.242506

# %% [markdown]
# La media de los residuos es aproximadamente cero.

# %%
import scipy.stats as stats

# Realizar el contraste de hipótesis
residuos = residuos['residuos']  # Extraer la columna de residuos del DataFrame

# Realizar el test t de una muestra
t_statistic, p_value = stats.ttest_1samp(residuos, 0)

# Imprimir los resultados del contraste
print('Estadístico t:', t_statistic)
print('Valor p:', p_value)
# Out:
# Estadístico t: -0.9359174675895852
# Valor p: 0.3493704435901195

# %% [markdown]
# Se acepta que la media de los residuos es cero.

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt

# Calcular la función de autocorrelación simple
plot_acf(residuos['residuos'], lags=10)
plt.xlabel('Lags')
plt.ylabel('Autocorrelación Simple')
plt.title('Función de Autocorrelación Simple')
plt.show()

# Calcular la función de autocorrelación parcial
plot_pacf(residuos['residuos'], lags=10)
plt.xlabel('Lags')
plt.ylabel('Autocorrelación Parcial')
plt.title('Función de Autocorrelación Parcial')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# El error del mdoelo es ruido blanco y con distribución nomral

# %%
# Exportar el dataframe como un excel
import pandas as pd

# Exportar el DataFrame a un archivo de Excel
df_cap.to_excel('df_cap.xlsx', index=False)

# %% [markdown]
# **Convertir en HTML**
#
# Haz clic en Archivo en la barra de menú superior de Google Colab.
# Selecciona Descargar .ipynb para descargar la notebook en formato .ipynb.
# Cambia la extensión del archivo descargado de .ipynb a .html. Por ejemplo, renómbralo como notebook.html.
